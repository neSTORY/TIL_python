# %%
import seaborn as sns
import pandas as pd

# %%
import altair as alt
from vega_datasets import data

source = data.barley()

alt.Chart(source).mark_bar().encode(
    x=alt.X('sum(yield)', stack="normalize"),
    y='variety',
    color='site'
)
# Out:
# alt.Chart(...)

# %%
source
# Out:
#         yield           variety  year             site
# 0    27.00000         Manchuria  1931  University Farm
# 1    48.86667         Manchuria  1931           Waseca
# 2    27.43334         Manchuria  1931           Morris
# 3    39.93333         Manchuria  1931        Crookston
# 4    32.96667         Manchuria  1931     Grand Rapids
# ..        ...               ...   ...              ...
# 115  58.16667  Wisconsin No. 38  1932           Waseca
# 116  47.16667  Wisconsin No. 38  1932           Morris
# 117  35.90000  Wisconsin No. 38  1932        Crookston
# 118  20.66667  Wisconsin No. 38  1932     Grand Rapids
# 119  29.33333  Wisconsin No. 38  1932           Duluth
#
# [120 rows x 4 columns]

# %%
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
df = titanic.dropna(subset=["age"])
df["survived"] = df["survived"]/714
df
# Out:
# <ipython-input-112-2e482c6db128>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["survived"] = df["survived"]/714
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0    0.000000       3    male  22.0      1      0   7.2500        S   Third
# 1    0.001401       1  female  38.0      1      0  71.2833        C   First
# 2    0.001401       3  female  26.0      0      0   7.9250        S   Third
# 3    0.001401       1  female  35.0      1      0  53.1000        S   First
# 4    0.000000       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 885  0.000000       3  female  39.0      0      5  29.1250        Q   Third
# ...

# %%
df.survived.sum()
# Out:
# 0.4061624649859944

# %%
alt.Chart(df).mark_bar().encode(
    x = "sum(survived)" ,
    y = "alive",
    color = "level"
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(df).mark_bar().encode(
    x = alt.X("sum(survived)" ,stack= "normalize"),
    y = "alive",
    color = "level"
)
# Out:
# alt.Chart(...)

# %%
bins = [0, 10, 20, 40, 60 ,100]
labels = ["영유아","청소년","청년","장년","노년"]

# %%
bins = [0, 10, 20, 40, 60 ,100]
level = pd.cut(titanic["age"], bins = bins, labels=labels)
titanic["level"] = level

# %%
alt.Chart(source).mark_bar().encode(
    x='variety',
    y='sum(yield)',
    color='site'
)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\altair\vegalite\v4\api.py in to_dict(self, *args, **kwargs)
#     371
#     372         try:
# --> 373             dct = super(TopLevelMixin, copy).to_dict(*args, **kwargs)
#     374         except jsonschema.ValidationError:
#     375             dct = None
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in to_dict(self, validate, ignore, context)
#     323             result = _todict(self._args[0], validate=sub_validate, context=context)
#     324         elif not self._args:
# --> 325             result = _todict(
#     326                 {k: v for k, v in self._kwds.items() if k not in ignore},
#     327                 validate=sub_validate,
#
# ~\anaconda3\lib\site-packages\altair\utils\schemapi.py in _todict(obj, validate, context)
# ...

# %%
titanic2 = titanic.dropna()
titanic2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 182 entries, 1 to 889
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     182 non-null    int64
#  1   pclass       182 non-null    int64
#  2   sex          182 non-null    object
#  3   age          182 non-null    float64
#  4   sibsp        182 non-null    int64
#  5   parch        182 non-null    int64
#  6   fare         182 non-null    float64
#  7   embarked     182 non-null    object
#  8   class        182 non-null    category
#  9   who          182 non-null    object
#  10  adult_male   182 non-null    bool
#  11  deck         182 non-null    category
#  12  embark_town  182 non-null    object
#  13  alive        182 non-null    object
#  14  alone        182 non-null    bool
#  15  level        182 non-null    category
# dtypes: bool(2), category(3), float64(2), int64(4), object(5)
# memory usage: 18.6+ KB

# %%
total = titanic["level"].value_counts(sort=False)
total.sum()
# Out:
# 714

# %%
some = titanic.groupby("level").sum()
# df = 
# df = pd.DataFrame(df)
some.survived = some.survived/714
some.reset_index(inplace=True)
some
# Out:
#   level  survived  pclass       age  sibsp  parch        fare  adult_male  \
# 0   영유아  0.053221     169    273.17    118     91   1947.8041           0
# 1   청소년  0.061625     291   1991.50     68     45   3395.8961          62
# 2    청년  0.214286     873  11280.50    132    116  13097.4408         249
# 3    장년  0.070028     229   6207.50     45     50   5420.5753          83
# 4    노년  0.007003      35   1452.50      3      6    910.1667          19
#
#    alone
# 0      1
# 1     65
# 2    249
# 3     71
# 4     18

# %%
some/total
# Out:
# level
# 영유아    0.593750
# 청소년    0.382609
# 청년     0.397403
# 장년     0.390625
# 노년     0.227273
# dtype: float64

# %%
alt.Chart(titanic).mark_bar().encode(
    x = alt.X("sum(survived)",stack= "normalize"),
    y = "age",
    color = "level"
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(some).mark_bar().encode(
    x = alt.X("sum(survived)",stack= "normalize"),
    y = "age",
    color = "level"
)
# Out:
# alt.Chart(...)

# %%
alt.Chart(some).mark_bar().encode(
    x = alt.X("survived",stack= "normalize"),
    y = "age",
    color = "level"
)
# Out:
# alt.Chart(...)

# %%
titanic = sns.load_dataset("titanic")
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
alt.X("sum(yield)")
# Out:
# X({
#   shorthand: 'sum(yield)'
# })

# %%
source = data.barley()
source
# Out:
#         yield           variety  year             site
# 0    27.00000         Manchuria  1931  University Farm
# 1    48.86667         Manchuria  1931           Waseca
# 2    27.43334         Manchuria  1931           Morris
# 3    39.93333         Manchuria  1931        Crookston
# 4    32.96667         Manchuria  1931     Grand Rapids
# ..        ...               ...   ...              ...
# 115  58.16667  Wisconsin No. 38  1932           Waseca
# 116  47.16667  Wisconsin No. 38  1932           Morris
# 117  35.90000  Wisconsin No. 38  1932        Crookston
# 118  20.66667  Wisconsin No. 38  1932     Grand Rapids
# 119  29.33333  Wisconsin No. 38  1932           Duluth
#
# [120 rows x 4 columns]
